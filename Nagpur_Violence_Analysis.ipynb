# %%
import ast
import json

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

import plotly.express as px
import plotly.graph_objects as go

from sentence_transformers import SentenceTransformer
from sklearn.manifold import TSNE
import torch

# %%
only_nagpur_data = pd.read_csv('/content/only_nagpur_df.csv')

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cuda

# %% [markdown]
# ## Generate embeddings using MPNet model

# %%
model = SentenceTransformer("sentence-transformers/all-mpnet-base-v2").to(device)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.4k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
titles = only_nagpur_data['translated_title'].fillna("").tolist()

batch_size = 32
embeddings = []

for i in tqdm(range(0, len(titles), batch_size), desc="Encoding Titles with MPNet"):
    batch = titles[i:i + batch_size]
    batch_embeddings = model.encode(batch, device=device)
    embeddings.extend(batch_embeddings)

only_nagpur_data['mpnet_embedding'] = [e.tolist() for e in embeddings]
# Out:
# Encoding Titles with MPNet: 100%|██████████| 96/96 [00:07<00:00, 13.41it/s]

# %% [markdown]
# ## Do the dimensionality reduction using t-SNE

# %%
# list of embeddings to NumPy array
embedding_matrix = np.array(only_nagpur_data["mpnet_embedding"].tolist())

# Run t-SNE
tsne = TSNE(
    n_components=2,
    perplexity=50,
    learning_rate=200,
    random_state=42,
    max_iter=2000,
)

tsne_result = tsne.fit_transform(embedding_matrix)

# %%
nagpur_tsne_df = only_nagpur_data.copy()

# Add reduced t-SNE coordinates
nagpur_tsne_df["x"] = tsne_result[:, 0]
nagpur_tsne_df["y"] = tsne_result[:, 1]

# %% [markdown]
# # :Semantic Representation Map

# %%
# Colored by Language
fig1 = px.scatter(
    nagpur_tsne_df,
    x="x",
    y="y",
    color="language",
    hover_data=["translated_title", "language", "source_name"],
    title="Semantic Map of Titles by Language",
    labels={"x": "t-SNE Dimension 1", "y": "t-SNE Dimension 2"},
)
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f32efe92-cffc-485b-b3ed-8e88e51afb6e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f32efe92-cffc-485b-b3ed-8e88e51afb6e")) {                    Plotly.newPlot(                        "f32efe92-cffc-485b-b3ed-8e88e51afb6e",                        [{"customdata":[["Nagpur violence: Bombay High Court banned the demolition of two accused's houses, administration reprimanded","hindi","Amar Ujala"],["Nagpur Violence: Curfew removed from all places in Nagpur, Fadnavis said- there is complete peace in the city, will not spare the culprits","hindi","Nbt Navbharattimes"],["The situation in Nagpur is completely peaceful, curfew was removed, Chief Minister Fadnavis said","hindi","Tv9 Bharatvarsh"],["Curfew ended 6 days after Nagpur violence, 113 people in custody, preparation to recover from rioters;Learn what happened so far","hindi","Ndtv"],["Aurangzeb Row |'Bulldozer will run on Nagpur rioters', CM Fadnavis roared!,Nagpur Violence |N18","hindi","News18 Punjabi News"],["Nagpur Row Update: Curfew removed from many areas of Nagpur, CM said, the situation completely controlled","hindi","One India"],["The situation in Nagpur is completely peaceful, curfew removed: Chief Minister Fadnavis","hindi","Theprint Hindi"],["Country newsThe situation in Nagpur is completely peaceful, curfew removed: Chief Minister Fadnavis","hindi","Latestly"],["Curfew Lifted In Nagpur: Curfew issued for the last 6 days after violence, citizens of Nagpur city get relief, police arrangements will remain","hindi","Latestly"],["The city has such situations in the city after 7 days of Nagpur Violence","hindi","Aaj Tak"],["Jabalpur Nagpur National Highway Accident: Driver overturned due to sleep gust, three passengers killed","hindi","Naidunia"],["Nagpur violence - CM said that recovered will be recovered from rioters, soon relief scheme","hindi","Bhaskar Hindi"],["Nagpur violence-Curfew completely removed from the city after 6 days: Patrol will continue with police deployment;Curfew was imposed in 11 areas after riots","hindi","Bhaskar"],["Curfew removed from all areas, now preparations for recovery from rioters ... 7 days after Nagpur violence, there are situations in the city","hindi","Aaj Tak"],["Curfew completely removed from Nagpur six days after violence","hindi","Theprint Hindi"],["Country newsCurfew completely removed from Nagpur six days after violence","hindi","Latestly"],["Shiv Sena leader Nirupam claims Nagpur violence to have a relationship with Bangladesh","hindi","Theprint Hindi"],["Aurangzeb Row: A big announcement of CM Fadnavis on Nagpur violence is trembling riot!Nagpur Violence | Fadnavis","hindi","News18 Punjabi News"],["Country newsShiv Sena leader Nirupam claims Nagpur violence to have a relationship with Bangladesh","hindi","Latestly"],["BBC, AP, NYT ... Nagpur's Muslim rioters for Western media, the film Chhava and the coined to blame Hindus as 'guilty': also broke the statement of CM Fadnavis.","hindi","Op India"],["Bus going from Ayodhya to Nagpur overturned: Accident in Ramanpur Valley;3 passengers killed, 25 injured","hindi","Bhaskar"],["Aurangzeb Row: Commando rioters landed on the streets of Nagpur no longer!Nagpur Violence | Fadnavis","hindi","News18 Punjabi News"],["'Do not do so with anyone' Innocent dies in Nagpur Violence, deceitful brother's pain","hindi","Asianet News Hindi"],["Big action in Nagpur violence: YouTuber arrested for treason, 190 inflammatory posts were removed","hindi","Ndtv"],["Aurangzeb Row: Bulldozer will run at Nagpur rioters' house angry CM Fadnavis. NAGPUR Violence Breaking","hindi","News18 Punjabi News"],["Nagpur Violence Update: Death of injured Irfan Ansari, know what are the situation in the area?" ...

# %% [markdown]
# # Temporal Shifts

# %%
nagpur_tsne_df['pubDate'] = pd.to_datetime(nagpur_tsne_df['pubDate'])
nagpur_tsne_df = nagpur_tsne_df.sort_values('pubDate')

# Step 2: Format date into string for animation frames
nagpur_tsne_df['pubDateStr'] = nagpur_tsne_df['pubDate'].dt.strftime('%Y-%m-%d')

# Step 3: Create the animation
fig = px.scatter(
    nagpur_tsne_df,
    x='x',
    y='y',
    animation_frame='pubDateStr',
    animation_group='article_id',
    color='language',
    hover_name='title',
    hover_data={'pubDateStr': True, 'language': True, 'translated_title': True},
    title='t-SNE Cluster Animation Nagpur Violence News Articles Over Time',
    labels={'x': 't-SNE X', 'y': 't-SNE Y'},
    opacity=0.7,
    height=700
)

fig.update_layout(
    title_font_size=22,
    xaxis=dict(showgrid=False),
    yaxis=dict(showgrid=False),
    legend_title_text='Language',
    showlegend=True
)

fig.layout.updatemenus[0].buttons[0].args[1]['frame']['duration'] = 600  # ms
fig.layout.updatemenus[0].buttons[0].args[1]['transition']['duration'] = 300

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6ab199e3-9a05-4ab7-9b9f-747889dd23ed" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ab199e3-9a05-4ab7-9b9f-747889dd23ed")) {                    Plotly.newPlot(                        "6ab199e3-9a05-4ab7-9b9f-747889dd23ed",                        [{"customdata":[["2025-03-09","english","Patanjali's Nagpur mega plant: Asia's largest orange processor opens; ₹1,500 crore boost for Vidarbha farmers |10 points"],["2025-03-09","english","Patanjali’s Nagpur mega plant: Asia’s largest orange processor opens; ₹1,500 crore boost for Vidarbha farmers |10 points - Mint"],["2025-03-09","english","Companies News Today Live Updates on March 9, 2025: Patanjali's Nagpur mega plant: Asia's largest orange processor opens; ₹1,500 crore boost for Vidarbha farmers |10 points"],["2025-03-09","english","Telangana: Two drivers killed as private bus hits stationary van in Adilabad"],["2025-03-09","english","Shahid Kapoor-Kareena Kapoor reunion at IIFA 2025: Actor calls it 'normal'; WATCH viral moment"],["2025-03-09","english","Telangana Tragedy: Two Drivers Killed in Collision Between Bus and Stationary Van on NH 44"],["2025-03-09","english","India News | Patanjali's Food and Herbal Park in Mihan to Begin Operations Today"],["2025-03-09","english","Patanjali food park in Nagpur will provide relief to Vidarbha farmers: Gadkari"],["2025-03-09","english","Patanjali food park in Nagpur will provide relief to Vidarbha farmers Gadkari"],["2025-03-09","english","Patanjali food park in Nagpur will provide relief to Vidarbha farmers: Devendra Fadnavis"],["2025-03-09","english","Patanjali Food Park: Construction Cost To Production Capacity, All About Nagpur’s New Facility"],["2025-03-09","english","Patanjali inaugurates Asia’s largest orange processing unit in Nagpur"],["2025-03-09","english","Patanjali inaugurates Asia's largest orange processing unit in Nagpur"],["2025-03-09","english","Business News | Patanjali Inaugurates Asia's Largest Orange Processing Unit in Nagpur"],["2025-03-09","english","Chhatrapati Shivaji Maharaj Is Our Role Model, Not Aurangzeb Who Robbed Country: Baba Ramdev"],["2025-03-09","english","Ramdev condemns vandalism at temple in US"],["2025-03-09","english","Union Minister Nitin Gadkari, Devendra Fadnavis, and Baba Ramdev inaugurate Mega Food and Herbal Park in Nagpur"],["2025-03-09","english","'No preservatives, no added sugar, 100% natural' – Patanjali’s Baba Ramdev on inauguration of Asia's largest orange processing unit in Nagpur - ET Now"],["2025-03-09","english","Baba Ramdev slams Trump's 'tariff terrorism,' accuses US President of threatening poor nations (WATCH)"],["2025-03-09","english","Chhatrapati Shivaji Maharaj is our role model, not Aurangzeb who robbed country: Baba Ramdev"],["2025-03-09","english","Patanjali Food and Herbal Park opens in Nagpur, CM Fadnavis announces orange processing facility"],["2025-03-09","english","Nitin Gadkari, Devendra Fadnavis inaugurate Patanjali’s Mega Food & Herbal Park in MIHAN, Nagpur"],["2025-03-09","english","Gadkari, Fadnavis inaugurate Patanjali's 'Mega Food & Herbal Park' at MIHAN Nagpur"],["2025-03-09","english","5 Years Of Covid: No Case In Nagpur Since Nov 2024"],["2025-03-09","english","IIM Nagpur to generate 2 MW solar power, achieve net-zero emissions"],["2025-03-09","english","Six Years On, Nagpur Metro Nears 9 Crore Commuters, Phase 2 Work Underway"],["2025-03-09","english","Gadkari advocates mix of Spanish Valencia orange with Nagpuri santra"],["2025-03-09","english","Patanjali rejected free land offers for Nagpur: Fadnavis"],["2025-03-09","english","Shri Nagpur Kutchhi Visa Oswal Mahila Mandal honours two inspiring women"]],"hovertemplate":"\u003cb\u003e%{hovertext ...
