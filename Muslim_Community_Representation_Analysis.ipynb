# %%
import ast
import json

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

import plotly.express as px
import plotly.graph_objects as go

from sentence_transformers import SentenceTransformer
from sklearn.manifold import TSNE
import torch

# %%
only_muslim_data = pd.read_csv('path/to/data-files/only_muslim_df.csv')

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
# Out:
# cuda

# %% [markdown]
# ## Generate embeddings using MPNet model

# %%
model = SentenceTransformer("sentence-transformers/all-mpnet-base-v2").to(device)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.4k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
titles = only_muslim_data['translated_title'].fillna("").tolist()

batch_size = 32
embeddings = []

for i in tqdm(range(0, len(titles), batch_size), desc="Encoding Titles with MPNet"):
    batch = titles[i:i + batch_size]
    batch_embeddings = model.encode(batch, device=device)
    embeddings.extend(batch_embeddings)

only_muslim_data['mpnet_embedding'] = [e.tolist() for e in embeddings]
# Out:
# Encoding Titles with MPNet: 100%|██████████| 69/69 [00:05<00:00, 12.37it/s]

# %% [markdown]
# ## Do the dimensionality reduction using t-SNE

# %%
# list of embeddings to NumPy array
embedding_matrix = np.array(only_muslim_data["mpnet_embedding"].tolist())

# Run t-SNE
tsne = TSNE(
    n_components=2,
    perplexity=50,
    learning_rate=200,
    random_state=42,
    max_iter=2000,
)

tsne_result = tsne.fit_transform(embedding_matrix)

# %%
muslim_tsne_df = only_muslim_data.copy()

# Add reduced t-SNE coordinates
muslim_tsne_df["x"] = tsne_result[:, 0]
muslim_tsne_df["y"] = tsne_result[:, 1]

# %% [markdown]
# # :Semantic Representation Map

# %%
# Colored by Language
fig1 = px.scatter(
    muslim_tsne_df,
    x="x",
    y="y",
    color="language",
    hover_data=["translated_title", "language", "source_name"],
    title="Semantic Map of Titles by Language",
    labels={"x": "t-SNE Dimension 1", "y": "t-SNE Dimension 2"},
)
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2d068c9d-b518-417f-be1b-918eb4b82af0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2d068c9d-b518-417f-be1b-918eb4b82af0")) {                    Plotly.newPlot(                        "2d068c9d-b518-417f-be1b-918eb4b82af0",                        [{"customdata":[["AIMPLB announces nationwide agitation against Waqf bill","english","Daily Excelsior"],["Gender disparity in Hajj inspector recruitment persists in J&K, sparks calls for policy reforms","english","Kashmir Reader"],["Religion-Based Reservation Violates Constitution: RSS","english","Kashmir Reader"],["Call for Chhatrapati Sambhaji Memorial Instead of Removing Aurangzeb's Tomb","english","Devdiscourse"],["Eat, pray, love: Hindu-Muslim unity on her iftar menu","english","The Times Of India"],["‘Withdraw Support For Waqf Bill Or Risk Losing Our Support’: AIMPLB Warns BJP Allies, Announces Nationwide Stir","english","Abp News"],["Religion-based quota not as per Constitution: RSS","english","The Economic Times"],["Curfew lifted in Nagpur, CM Fadnavis says situation is completely peaceful days after violence by Muslim mob","english","Op India"],["AIMPLB announces nationwide protests against amendment of Waqf Bill","english","Business Standard"],["AIMPLB announces nationwide agitation against Waqf Bill","english","Orissa Post"],["Aurangzeb: Purging bigotry and brutality","english","Organiser Weekly"],["Muslim organisations boycott Nitish Kumar’s Iftar over his support to Waqf Amendment Bill - The Hindu","english","Google News"],["BJP's Jagadish Shettar slams 'undemocratic' suspension of 18 MLAs in Karnataka, urges withdrawal","english","Asianet Newsable"],["Aurangzeb: A tomb of tyranny","english","Organiser Weekly"],["'If 5% More Hindu Votes Come To BJP, We’ll Win Bengal': Suvendu Adhikari’s Hindutva Pitch For 2026 Polls","english","Abp News"],["Muslim organisations boycott Nitish Kumar’s Iftar over his support to Waqf Amendment Bill","english","The Hindu"],["Akhilesh Yadav Defends SP MP Ramjilal Suman Over Rana Sanga Remark, BJP Calls It 'Anti-Hindu Mindset'","english","Abp News"],["AIMPLB announces nationwide agitation against Waqf Bill","english","The Week"],["India News | AIMPLB Announces Nationwide Agitation Against Waqf Bill","english","Latestly"],["Pakistan's Pursuit of Peace: A Just Settlement for Kashmir","english","Devdiscourse"],["All India Muslim Personal Law Board Announces Nationwide Movement Against Waqf Amendment Bill","english","Zee News"],["Nagpur Violence and Aurangzeb: A play-book conspiracy","english","Organiser Weekly"],["Why iconise someone who was against India’s ethos, asks RSS general secretary over Aurangzeb’s tomb row - The Hindu","english","Google News"],["Balochistan: Fight for pride heritage","english","Organiser Weekly"],["DH Evening Brief | No cash found at judge's house? New evidence shows otherwise; RSS attacks Karnataka govt over Muslim quota","english","Deccan Herald"],["AIMIM gears up for Youmul Quran on last Friday of Ramzan","english","Siasat.com"],["Telangana CM congratulates Prince Rahim Aga Khan","english","Yes Punjab News"],["Akhilesh Yadav defends Ramjilal Suman's 'Rana Sanga traitor' remark","english","The Times Of India"],["Muslim law board announces nationwide 'agitation' against Waqf Amendment Bill","english","Asianet Newsable"],["AIMPLB calls for pan-India movement against Waqf (Amendment) Bill","english","Yes Punjab News"],["MUSLIM population to grow most in these countries in by 2030, Pakistan, Bangladesh, Afghanistan to..., check full list here, some name will surprise you","english","India"],["Congress leader disapproves of 'Iftaar' boycott by Muslim bodies","english","The Week"],["Controversy Stirs: Muslim Bodies ...

# %% [markdown]
# # Change Over Time

# %%
muslim_tsne_df['pubDate'] = pd.to_datetime(muslim_tsne_df['pubDate'])
muslim_tsne_df = muslim_tsne_df.sort_values('pubDate')

# Step 2: Format date into string for animation frames
muslim_tsne_df['pubDateStr'] = muslim_tsne_df['pubDate'].dt.strftime('%Y-%m-%d')

# Step 3: Create the animation
fig = px.scatter(
    muslim_tsne_df,
    x='x',
    y='y',
    animation_frame='pubDateStr',
    animation_group='article_id',
    color='language',
    hover_name='title',
    hover_data={'pubDateStr': True, 'language': True, 'translated_title': True},
    title='t-SNE Cluster Animation Nagpur Violence News Articles Over Time',
    labels={'x': 't-SNE X', 'y': 't-SNE Y'},
    opacity=0.7,
    height=700
)

fig.update_layout(
    title_font_size=22,
    xaxis=dict(showgrid=False),
    yaxis=dict(showgrid=False),
    legend_title_text='Language',
    showlegend=True
)

fig.layout.updatemenus[0].buttons[0].args[1]['frame']['duration'] = 600  # ms
fig.layout.updatemenus[0].buttons[0].args[1]['transition']['duration'] = 300

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0649d915-5620-4eb0-8c4b-1c1770774871" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0649d915-5620-4eb0-8c4b-1c1770774871")) {                    Plotly.newPlot(                        "0649d915-5620-4eb0-8c4b-1c1770774871",                        [{"customdata":[["2025-03-09","english","SC rejects plea against early leave for Muslims during Ramzan"],["2025-03-09","english","Maharashtra has received over 100k ‘love jihad’ complaints: CM Fadnavis"],["2025-03-09","english","Waqf Bill: AIMPLB mounts pressure on TDP, JDU with series of protests - The Indian Express"],["2025-03-09","english","AMU does U-turn, grants permission to hold Holi celebrations after facing backlash from Hindus over initial refusal"],["2025-03-09","english","Death Toll Rises To 1,000 After Syrian Security Forces & Assad Loyalists Engage In Fierce Clashes"],["2025-03-09","english","Nobody Wants Them: Trump Asks Muslim Nations to Resettle Gaza's Population, but They're Rejecting It"],["2025-03-09","english","Eighth Day Of Ramadan – Check The Iftar Timings For Delhi, Mumbai, Lucknow, And Other Cities"],["2025-03-09","english","1,000 Killed In 2 Days Of Revenge Killings In Syria, UN Officials Call For Civilians Protection"],["2025-03-09","english","Roza Pop is here"],["2025-03-09","english","Syria: Revenge killings claim 1000 lives so far, Alawite women paraded naked on streets by security forces"],["2025-03-09","english","Diplomatic Maneuvers in the Middle East: Israel–Hamas Ceasefire Talks Progress Amid Tensions"],["2025-03-09","english","'Advance the negotiations': Israel to send delegation to Qatar for ceasefire talks"],["2025-03-09","english","UP: Imam, 8 others arrested for announcing Iftar on loudspeaker"],["2025-03-09","english","Holi celebrations permitted at AMU after denial amid students’ demands"],["2025-03-09","english","Controversy Surrounds Proposed Amendments to the Waqf Act"],["2025-03-09","english","Centre wants to set 'Hindu-Muslim' narrative via Waqf amendments Sena UBT MP"],["2025-03-09","english","Centre wants to set 'Hindu-Muslim' narrative via Waqf amendments: Sena (UBT) MP"],["2025-03-09","english","Centre wants to set ‘Hindu-Muslim’ narrative via Waqf amendments: Sena (UBT) MP"],["2025-03-09","english","Centre Wants To Set ‘Hindu-Muslim’ Narrative via Waqf Amendments, Says Shiv Sena (UBT) MP Arvind Sawant"],["2025-03-09","english","Video: 17 South Koreans accept Islam in Ramzan"],["2025-03-09","english","Centre wants to set 'Hindu-Muslim' narrative via Waqf amendments: Sena (UBT) MP"],["2025-03-09","english","Centre setting Hindu-Muslim narrative via waqf amendments: Sena (UBT) MP"],["2025-03-09","english","VHP organizes padayatra in Mangaluru to advocate for Hindu protection"],["2025-03-09","english","Who Are The Alawites Of Syria? Assad Loyalists Being Targeted By Syrian Security Forces"],["2025-03-09","english","1000 killed in two days, electricity and drinking water cut off; What’s happening in this Muslim nation"],["2025-03-09","english","Centre wants to set `Hindu-Muslim` narrative via Waqf amendments: Sena (UBT) MP"],["2025-03-09","english","India News | Supreme Court Should Take Congizance: Congress MP Imraan Masood on UP Policeman's 'Holi Vs Namaaz' Remarks"],["2025-03-09","english","Ramadan 2025: Sehri, Iftaar timings for March 10 in Delhi, Kolkata, Lucknow, Hyderabad among other cities — Details"],["2025-03-09","english","Denied sex by girlfriends and wives during Ramazan, Muslim youths rape their ‘friend’ teenaged boy, kill him brutally and dump body in a well in UP"],["2025-03-09","english","Muslim youths rape and kill their ‘friend’ teenaged boy because of no sex during Ramazan - OpIndia"],["2025-03-09","english" ...
